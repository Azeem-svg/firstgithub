# %%
# import libraries
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
# import your data
df=pd.read_csv("multiple linear regression.csv")
df.head()
# Out:
#     age  distance  YearsExperience  Salary
# 0  31.1     77.75              1.1   39343
# 1  31.3     78.25              1.3   46205
# 2  31.5     78.75              1.5   37731
# 3  32.0     80.00              2.0   43525
# 4  32.2     80.50              2.2   39891

# %%
df.isnull().sum()
# Out:
# age                0
# distance           0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x= df[['age','distance','YearsExperience']]
y= df['Salary']

# %%
x.head()
# Out:
#     age  distance  YearsExperience
# 0  31.1     77.75              1.1
# 1  31.3     78.25              1.3
# 2  31.5     78.75              1.5
# 3  32.0     80.00              2.0
# 4  32.2     80.50              2.2

# %%
y.head()
# Out:
# 0    39343
# 1    46205
# 2    37731
# 3    43525
# 4    39891
# Name: Salary, dtype: int64

# %%
plt.subplot(2,2,1)
plt.scatter(x['age'],y)
plt.subplot(2,2,2)
plt.scatter(x['distance'],y)
plt.subplot(2,2,3,)
plt.scatter(x['YearsExperience'],y)

# %%
plt.style.use('default')

fig = plt.figure(figsize=(16, 8))

ax = fig.add_subplot(111, projection='3d')
x1=(x)
x2=(x)
x3=(x)
ax.scatter(x1,x2,x3, c='r', marker='o')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression().fit(x_train, y_train)

# %%
print('score of test data=', model.score(x_test, y_test))
print('score of train data=', model.score(x_train, y_train))
# Out:
# score of test data= 0.988401541985491
# score of train data= 0.9409532368371482

# %%
reg=LinearRegression().fit(x_test, y_test)
print('Test score=', reg.score(x_test, y_test))
print('train score=', reg.score(x_train, y_train))
# Out:
# Test score= 0.9934433748762496
# train score= 0.930766846826246

# %%
plt.style.use('default')

fig = plt.figure(figsize=(12, 4))


ax = fig.add_subplot(111, projection='3d')
x1=('x_train')
x2=(x_train])
x3=(x_train])
ax.scatter('x1,x2,x3, c='r', marker=0)
# Out:
#   File "C:\Users\Haier\AppData\Local\Temp/ipykernel_3272/2556199172.py", line 8
#     x2=(x_train])
#                ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %%
model.predict([[31.3,77.5,1.1]])
# Out:
# C:\Users\Haier\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-2.42122788e+15])

# %%
# an attempt to draw a single prdicted value (failed)
model.predict([[31.3,77.5,1.1]])
plt.style.use('default')

fig = plt.figure(figsize=(12, 4))

ax1 = fig.add_subplot(111, projection='3d')
ax.scatter(model.predict([[31.3,77.5,1.1]]), c='r', marker='o')
# Out:
# C:\Users\Haier\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\Haier\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7424/3962961087.py in <module>
#       6
#       7 ax1 = fig.add_subplot(111, projection='3d')
# ----> 8 ax.scatter(model.predict([[31.3,77.5,1.1]]), c='r', marker='o')
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
plt.style.use('default')

fig = plt.figure(figsize=(12, 4))

ax1 = fig.add_subplot(131, projection='3d')
ax2 = fig.add_subplot(132, projection='3d')
ax3 = fig.add_subplot(133, projection='3d')

axes = [ax1, ax2, ax3]
for ax in axes:
    ax.plot(x, y)
    ax.scatter(x_train, y_train,facecolor=(0,0,0,0), s=20, edgecolor='#70b3f0')
    ax.set_xlabel('Porosity (%)', fontsize=12)
    ax.set_ylabel('VR', fontsize=12)
    ax.set_zlabel('Gas Prod. (Mcf/day)', fontsize=12)
    ax.locator_params(nbins=4, axis='x')
    ax.locator_params(nbins=5, axis='x')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7424/2536680817.py in <module>
#      10 for ax in axes:
#      11     ax.plot(x, y)
# ---> 12     ax.scatter(x_train, y_train,facecolor=(0,0,0,0), s=20, edgecolor='#70b3f0')
#      13
#      14
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2377         zs_orig = zs
#    2378
# ...

# %%
import matplotlib.pyplot 
fig = matplotlib.pyplot.figure()
ax  = fig.add_subplot(111, projection = '3d')

ax.plot(x_train, y_train, color = 'b')
ax.plot(x_test, x_test, color = 'r')

ax.scatter(x_train, x_train, y, color = 'g', marker = "o")
ax.scatter(x_test, y_test, y, color = 'y', marker = "^")

matplotlib.pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7424/39341545.py in <module>
#       6 ax.plot(x_test, x_test, color = 'r')
#       7
# ----> 8 ax.scatter(x_train, x_train, y, color = 'g', marker = "o")
#       9 ax.scatter(x_test, y_test, y, color = 'y', marker = "^")
#      10
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2377         zs_orig = zs
#    2378
# ...

# %%
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
ax.scatter3D(x_train, y_train, color = "green")
plt.title("simple 3D scatter plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7424/3052281377.py in <module>
#       1 fig = plt.figure(figsize = (10, 7))
#       2 ax = plt.axes(projection ="3d")
# ----> 3 ax.scatter3D(x_train, y_train, color = "green")
#       4 plt.title("simple 3D scatter plot")
#       5 plt.show()
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2377         zs_orig = zs
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
# ax.scatter(X['foo'], X['bar'], Y, label='data')

# for x0, x1, yt, yp in zip(x_test['foo'], x_test['bar'], y_test, y_train):
#     ax.plot([x0, x0], [x1, x1], [yt, yp], color='red')

ax.scatter(x_train, y_train, x_test, color='red', marker='s', label='prediction') 

ax.set_xlabel('X0')
ax.set_ylabel('X1')
ax.set_zlabel('y')
ax.legend()
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13616/662887485.py in <module>
#       6 #     ax.plot([x0, x0], [x1, x1], [yt, yp], color='red')
#       7
# ----> 8 ax.scatter(x_train, y_train, y_train, color='red', marker='s', label='prediction')
#       9
#      10 ax.set_xlabel('X0')
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in scatter(self, xs, ys, zs, zdir, s, c, depthshade, *args, **kwargs)
#    2377         zs_orig = zs
#    2378
# ...

# %% [markdown]
# - import seaborn as sns didn't work
# - sns.regplot(x=y_train, y=y_test, ci=None, color="b")

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train, y_train)
plt.plot(x_train, model.predict(x_train), color="green")
plt.xlabel("tajurba")
plt.ylabel("tankhwa")
plt.title("train plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13616/3707649035.py in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.scatter(x_train, y_train)
#       3 plt.plot(x_train, model.predict(x_train), color="green")
#       4 plt.xlabel("tajurba")
#       5 plt.ylabel("tankhwa")
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2805         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2806         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2807     __ret = gca().scatter(
#    2808         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2809         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ...

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, model.predict(x_test), color="green")
plt.xlabel("linear")
plt.ylabel("tankhwa")
plt.title("train plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13616/710065700.py in <module>
# ----> 1 plt.scatter(x_test, y_test)
#       2 plt.plot(x_test, model.predict(x_test), color="green")
#       3 plt.xlabel("linear")
#       4 plt.ylabel("tankhwa")
#       5 plt.title("train plot")
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2805         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2806         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2807     __ret = gca().scatter(
#    2808         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2809         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ...

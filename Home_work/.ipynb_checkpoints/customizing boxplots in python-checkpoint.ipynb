# %%
import seaborn as sns
import pandas as pd
import numpy as np

kashti= sns.load_dataset("titanic")
sns.boxplot(x="survived", y="age", data=kashti)
# plt.show()
# Out:
# <AxesSubplot:xlabel='survived', ylabel='age'>

# %%
import matplotlib.pyplot as plt
p1=sns.boxplot(x="survived", y="age", data=kashti)
plt.show()

# %%
p1=sns.boxplot(x="survived", y="age", showmeans=True, data=kashti)
plt.show()

# %%
p1=sns.boxplot(x="survived", y="age", showmeans=True, meanprops= {"marker":"*",
                                                                 "markersize": "12",
                                                                 "markeredgecolor":"pink"},
               data=kashti)
sns.FacetGrid(kashti, col ="survived",  hue ="age")
# show labels
plt.xlabel("how many survived", size= 20,weight='bold')
plt.ylabel("Age (years)", size=18,weight='bold')
plt.title("khasma nu kha", size=14, weight='bold')
plt.show()

# %%
##facet wrap and facet grid"" assignment

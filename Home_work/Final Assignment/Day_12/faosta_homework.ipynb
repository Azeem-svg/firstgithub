# %%
# home work 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
practice =pd.read_csv("as.csv")
practice.head(5)
# Out:
#   Domain Code    Domain  Area Code      Area  Element Code Element  Item Code  \
# 0          RL  Land Use        165  Pakistan          5110    Area       6621
# 1          RL  Land Use        165  Pakistan          5110    Area       6650
# 2          RL  Land Use        165  Pakistan          5110    Area       6655
# 3          RL  Land Use        165  Pakistan          5110    Area       6655
# 4          RL  Land Use        165  Pakistan          5110    Area       6650
#
#                                     Item  Year Code  Year     Unit  Value  \
# 0                            Arable land       1961  1961  1000 ha  30580
# 1             Land under permanent crops       1961  1961  1000 ha    150
# 2  Land under perm. meadows and pastures       1961  1961  1000 ha   5000
# 3  Land under perm. meadows and pastures       1962  1962  1000 ha   5000
# 4             Land under permanent crops       1962  1962  1000 ha    150
#
# ...

# %%
#saving practice data
practice.to_csv('as.csv')
practice.head(4)
# Out:
#   Domain Code    Domain  Area Code      Area  Element Code Element  Item Code  \
# 0          RL  Land Use        165  Pakistan          5110    Area       6621
# 1          RL  Land Use        165  Pakistan          5110    Area       6650
# 2          RL  Land Use        165  Pakistan          5110    Area       6655
# 3          RL  Land Use        165  Pakistan          5110    Area       6655
#
#                                     Item  Year Code  Year     Unit  Value  \
# 0                            Arable land       1961  1961  1000 ha  30580
# 1             Land under permanent crops       1961  1961  1000 ha    150
# 2  Land under perm. meadows and pastures       1961  1961  1000 ha   5000
# 3  Land under perm. meadows and pastures       1962  1962  1000 ha   5000
#
#   Flag                                   Flag Description
# 0    W  Data reported on country official publications...
# 1    F                                       FAO estimate
# ...

# %%
# basic statistics
practice.describe()
# Out:
#        Area Code  Element Code    Item Code    Year Code         Year  \
# count      177.0         177.0   177.000000   177.000000   177.000000
# mean       165.0        5110.0  6642.000000  1990.000000  1990.000000
# std          0.0           0.0    15.031407    17.077697    17.077697
# min        165.0        5110.0  6621.000000  1961.000000  1961.000000
# 25%        165.0        5110.0  6621.000000  1975.000000  1975.000000
# 50%        165.0        5110.0  6650.000000  1990.000000  1990.000000
# 75%        165.0        5110.0  6655.000000  2005.000000  2005.000000
# max        165.0        5110.0  6655.000000  2019.000000  2019.000000
#
#               Value
# count    177.000000
# mean   12087.028249
# std    13387.595177
# min      150.000000
# 25%      793.000000
# 50%     5000.000000
# 75%    30310.000000
# max    33140.000000

# %%
# dropping few column
new_practice= practice.drop(['Area Code', 'Item Code', 'Value'], axis=1)
new_practice.head(5)
# Out:
#   Domain Code    Domain      Area  Element Code Element  \
# 0          RL  Land Use  Pakistan          5110    Area
# 1          RL  Land Use  Pakistan          5110    Area
# 2          RL  Land Use  Pakistan          5110    Area
# 3          RL  Land Use  Pakistan          5110    Area
# 4          RL  Land Use  Pakistan          5110    Area
#
#                                     Item  Year Code  Year     Unit Flag  \
# 0                            Arable land       1961  1961  1000 ha    W
# 1             Land under permanent crops       1961  1961  1000 ha    F
# 2  Land under perm. meadows and pastures       1961  1961  1000 ha    F
# 3  Land under perm. meadows and pastures       1962  1962  1000 ha    F
# 4             Land under permanent crops       1962  1962  1000 ha    F
#
#                                     Flag Description
# 0  Data reported on country official publications...
# 1                                       FAO estimate
# ...

# %%
new_practice.mean()
# Out:
# C:\Users\Haier\AppData\Local\Temp/ipykernel_7700/1604023365.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   new_practice.mean()
# Element Code    5110.0
# Year Code       1990.0
# Year            1990.0
# dtype: float64

# %%
new_practice.value_counts(["Item"])
# Out:
# Item
# Arable land                              59
# Land under perm. meadows and pastures    59
# Land under permanent crops               59
# dtype: int64

# %%
new_practice.groupby(['Item', 'Year']).mean()
# Out:
#                                  Element Code  Year Code
# Item                       Year
# Arable land                1961        5110.0     1961.0
#                            1962        5110.0     1962.0
#                            1963        5110.0     1963.0
#                            1964        5110.0     1964.0
#                            1965        5110.0     1965.0
# ...                                       ...        ...
# Land under permanent crops 2015        5110.0     2015.0
#                            2016        5110.0     2016.0
#                            2017        5110.0     2017.0
#                            2018        5110.0     2018.0
#                            2019        5110.0     2019.0
#
# [177 rows x 2 columns]

# %%
new_practice.head()
# Out:
#   Domain Code    Domain      Area  Element Code Element  \
# 0          RL  Land Use  Pakistan          5110    Area
# 1          RL  Land Use  Pakistan          5110    Area
# 2          RL  Land Use  Pakistan          5110    Area
# 3          RL  Land Use  Pakistan          5110    Area
# 4          RL  Land Use  Pakistan          5110    Area
#
#                                     Item  Year Code  Year     Unit Flag  \
# 0                            Arable land       1961  1961  1000 ha    W
# 1             Land under permanent crops       1961  1961  1000 ha    F
# 2  Land under perm. meadows and pastures       1961  1961  1000 ha    F
# 3  Land under perm. meadows and pastures       1962  1962  1000 ha    F
# 4             Land under permanent crops       1962  1962  1000 ha    F
#
#                                     Flag Description
# 0  Data reported on country official publications...
# 1                                       FAO estimate
# ...

# %%
new_practice[new_practice['Year'] > 2003]
# Out:
#     Domain Code    Domain      Area  Element Code Element  \
# 129          RL  Land Use  Pakistan          5110    Area
# 130          RL  Land Use  Pakistan          5110    Area
# 131          RL  Land Use  Pakistan          5110    Area
# 132          RL  Land Use  Pakistan          5110    Area
# 133          RL  Land Use  Pakistan          5110    Area
# 134          RL  Land Use  Pakistan          5110    Area
# 135          RL  Land Use  Pakistan          5110    Area
# 136          RL  Land Use  Pakistan          5110    Area
# 137          RL  Land Use  Pakistan          5110    Area
# 138          RL  Land Use  Pakistan          5110    Area
# 139          RL  Land Use  Pakistan          5110    Area
# 140          RL  Land Use  Pakistan          5110    Area
# 141          RL  Land Use  Pakistan          5110    Area
# 142          RL  Land Use  Pakistan          5110    Area
# 143          RL  Land Use  Pakistan          5110    Area
# ...

# %%
new_practice[new_practice['Year'] > 2003].mean()
# Out:
# C:\Users\Haier\AppData\Local\Temp/ipykernel_7700/1736838793.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   new_practice[new_practice['Year'] > 2003].mean()
# Element Code    5110.0
# Year Code       2011.5
# Year            2011.5
# dtype: float64

# %%
new_practice[new_practice['Year'] > 2003].groupby(['Item', 'Flag']).mean()
# Out:
#                                             Element Code    Year Code  \
# Item                                  Flag
# Arable land                           Fm          5110.0  2018.500000
#                                       Q           5110.0  2012.500000
#                                       W           5110.0  2005.500000
# Land under perm. meadows and pastures Fm          5110.0  2011.500000
# Land under permanent crops            Fm          5110.0  2018.500000
#                                       Q           5110.0  2010.636364
#                                       W           5110.0  2010.000000
#
#                                                    Year
# Item                                  Flag
# Arable land                           Fm    2018.500000
#                                       Q     2012.500000
#                                       W     2005.500000
# Land under perm. meadows and pastures Fm    2011.500000
# ...
